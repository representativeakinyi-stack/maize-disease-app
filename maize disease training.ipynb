# %%
maize cnn training.ipynb

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np

# %%
print("All libraries working correctly")
# Out:
# All libraries working correctly

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_data = train_datagen.flow_from_directory(
    'dataset',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_data = train_datagen.flow_from_directory(
    'dataset',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 0 images belonging to 5 classes.
# Found 0 images belonging to 5 classes.

# %%
import os

print("CURRENT LOCATION:")
print(os.getcwd())

print("\nINSIDE CURRENT FOLDER:")
print(os.listdir('.'))

print("\nINSIDE DATASET FOLDER:")
print(os.listdir('dataset'))
# Out:
# CURRENT LOCATION:
# C:\Users\Rose\maize-disease-project
#
# INSIDE CURRENT FOLDER:
# ['.ipynb_checkpoints', 'dataset', 'maize disease training.ipynb', 'models', 'notebooks', 'static', 'templates']
#
# INSIDE DATASET FOLDER:
# ['.ipynb_checkpoints', 'common_rust', 'gray_leaf_spot', 'healthy', 'northern_leaf_blight']

# %%
import os

for folder in os.listdir('dataset'):
    path = os.path.join('dataset', folder)
    if os.path.isdir(path):
        print(folder, "->", len(os.listdir(path)))
# Out:
# .ipynb_checkpoints -> 0
# common_rust -> 0
# gray_leaf_spot -> 0
# healthy -> 0
# northern_leaf_blight -> 0

# %%
import os

print(os.listdir('dataset/healthy'))
# Out:
# ['img (1).jpg']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(rescale=1./255)

data = datagen.flow_from_directory(
    'dataset',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 1 images belonging to 5 classes.

# %%
import os

for folder in os.listdir('dataset'):
    print(folder, "->", len(os.listdir(f'dataset/{folder}')))
# Out:
# .ipynb_checkpoints -> 0
# common_rust -> 10
# gray_leaf_spot -> 10
# healthy -> 10
# northern_leaf_blight -> 10

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Rose\maize-disease-project

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(rescale=1./255)

data = datagen.flow_from_directory(
    'dataset',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 40 images belonging to 5 classes.

# %%
import os

print("Dataset folders:")
for f in os.listdir('dataset'):
    print(f)
# Out:
# Dataset folders:
# .ipynb_checkpoints
# common_rust
# gray_leaf_spot
# healthy
# northern_leaf_blight

# %%
import os
print(os.listdir('dataset'))
# Out:
# ['.ipynb_checkpoints', 'common_rust', 'gray_leaf_spot', 'healthy', 'northern_leaf_blight']

# %%
import os

for f in os.listdir('dataset'):
    print(f)
# Out:
# .ipynb_checkpoints
# common_rust
# gray_leaf_spot
# healthy
# northern_leaf_blight

# %%
import shutil
import os

path = os.path.join('dataset', '.ipynb_checkpoints')

if os.path.exists(path):
    shutil.rmtree(path)
    print("Removed .ipynb_checkpoints")
else:
    print("Already removed or not found")
# Out:
# Removed .ipynb_checkpoints

# %%
import os
print(os.listdir('dataset'))
# Out:
# ['common_rust', 'gray_leaf_spot', 'healthy', 'northern_leaf_blight']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(rescale=1./255)

data = datagen.flow_from_directory(
    'dataset',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 40 images belonging to 4 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()

# Convolution + Pooling
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(128, (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))

# Flatten
model.add(Flatten())

# Fully connected layers
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

# Output layer (4 classes)
model.add(Dense(4, activation='softmax'))
# Out:
# C:\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
history = model.fit(
    data,
    epochs=10
)
# Out:
# Epoch 1/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 337ms/step - accuracy: 0.2000 - loss: 1.4613
# Epoch 2/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.2000 - loss: 1.6638
# Epoch 3/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 313ms/step - accuracy: 0.2250 - loss: 1.3099
# Epoch 4/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 356ms/step - accuracy: 0.3000 - loss: 1.2256
# Epoch 5/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 1000ms/step - accuracy: 0.6750 - loss: 0.9776
# Epoch 6/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 319ms/step - accuracy: 0.6250 - loss: 0.8516
# Epoch 7/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7000 - loss: 0.6990
# Epoch 8/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 938ms/step - accuracy: 0.8750 - loss: 0.4405
# Epoch 9/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8000 - loss: 0.4607
# Epoch 10/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8250 - loss: 0.3241

# %%
model.save("maize_disease_model.h5")
print("Model saved successfully")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully
