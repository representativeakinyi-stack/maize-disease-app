# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_data = datagen.flow_from_directory(
    "dataset",
    target_size=(128,128),
    batch_size=32,
    class_mode="categorical",
    subset="training"
)

val_data = datagen.flow_from_directory(
    "dataset",
    target_size=(128,128),
    batch_size=32,
    class_mode="categorical",
    subset="validation"
)
# Out:
# Found 32 images belonging to 4 classes.
# Found 8 images belonging to 4 classes.

# %%
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(128,128,3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(4, activation='softmax')
])
# Out:
# c:\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
model.fit(train_data, validation_data=val_data, epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.2812 - loss: 1.3881 - val_accuracy: 0.2500 - val_loss: 1.7395
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.2188 - loss: 1.8607 - val_accuracy: 0.2500 - val_loss: 1.4211
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.4375 - loss: 1.3595 - val_accuracy: 0.2500 - val_loss: 1.3438
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.3438 - loss: 1.3778 - val_accuracy: 0.3750 - val_loss: 1.2809
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.4062 - loss: 1.2546 - val_accuracy: 0.2500 - val_loss: 1.2673
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.3438 - loss: 1.2597 - val_accuracy: 0.3750 - val_loss: 1.1818
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.4688 - loss: 1.1346 - val_accuracy: 0.6250 - val_loss: 1.1298
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.7188 - loss: 1.0656 - val_accuracy: 0.7500 - val_loss: 1.0380
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.7812 - loss: 0.9476 - val_accuracy: 0.6250 - val_loss: 0.9689
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.4375 - loss: 0.9698 - val_accuracy: 0.7500 - val_loss: 0.8768

# %%
model.save("model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
train_data = datagen.flow_from_directory(
    "../dataset",
    target_size=(128,128),
    batch_size=32,
    class_mode="categorical",
    subset="training"
)

val_data = datagen.flow_from_directory(
    "../dataset",
    target_size=(128,128),
    batch_size=32,
    class_mode="categorical",
    subset="validation"
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 train_data = datagen.flow_from_directory(
#       2     "../dataset",
#       3     target_size=(128,128),
#       4     batch_size=32,
#       5     class_mode="categorical",
#       6     subset="training"
#       7 )
#       9 val_data = datagen.flow_from_directory(
#      10     "../dataset",
#      11     target_size=(128,128),
#    (...)
#      14     subset="validation"
#      15 )
#
# File c:\Python310\lib\site-packages\keras\src\legacy\preprocessing\image.py:1136, in ImageDataGenerator.flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1118 def flow_from_directory(
#    1119     self,
#    1120     directory,
#    (...)
#    1134     keep_aspect_ratio=False,
#    1135 ):
# -> 1136     return DirectoryIterator(
#    1137         directory,
#    1138         self,
#    1139         target_size=target_size,
#    1140         color_mode=color_mode,
#    1141         keep_aspect_ratio=keep_aspect_ratio,
#    1142         classes=classes,
#    1143         class_mode=class_mode,
#    1144         data_format=self.data_format,
#    1145         batch_size=batch_size,
#    1146         shuffle=shuffle,
#    1147         seed=seed,
#    1148         save_to_dir=save_to_dir,
#    1149         save_prefix=save_prefix,
#    1150         save_format=save_format,
#    1151         follow_links=follow_links,
#    1152         subset=subset,
#    1153         interpolation=interpolation,
#    1154         dtype=self.dtype,
#    1155     )
#
# File c:\Python310\lib\site-packages\keras\src\legacy\preprocessing\image.py:456, in DirectoryIterator.__init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio, dtype)
#     454 if not classes:
#     455     classes = []
# --> 456     for subdir in sorted(os.listdir(directory)):
#     457         if os.path.isdir(os.path.join(directory, subdir)):
#     458             classes.append(subdir)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '../dataset'

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Rose\maize-disease-project

# %%
train_data = datagen.flow_from_directory(
    "dataset",
    target_size=(128,128),
    batch_size=32,
    class_mode="categorical",
    subset="training"
)
# Out:
# Found 278 images belonging to 4 classes.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_data = datagen.flow_from_directory(
    "dataset",
    target_size=(128,128),
    batch_size=32,
    class_mode="categorical",
    subset="training"
)

val_data = datagen.flow_from_directory(
    "dataset",
    target_size=(128,128),
    batch_size=32,
    class_mode="categorical",
    subset="validation"
)
# Out:
# Found 278 images belonging to 4 classes.
# Found 69 images belonging to 4 classes.

# %%
print(train_data.class_indices)
# Out:
# {'common_rust': 0, 'gray_leaf_spot': 1, 'healthy': 2, 'northern_leaf_blight': 3}

# %%
model.fit(train_data, validation_data=val_data, epochs=20)
# Out:
# Epoch 1/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 354ms/step - accuracy: 0.9676 - loss: 0.1405 - val_accuracy: 0.8406 - val_loss: 0.4883
# Epoch 2/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 314ms/step - accuracy: 0.9712 - loss: 0.0919 - val_accuracy: 0.8261 - val_loss: 0.5452
# Epoch 3/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 357ms/step - accuracy: 0.9748 - loss: 0.0801 - val_accuracy: 0.8841 - val_loss: 0.6508
# Epoch 4/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 301ms/step - accuracy: 0.9748 - loss: 0.0690 - val_accuracy: 0.8261 - val_loss: 0.6371
# Epoch 5/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 337ms/step - accuracy: 0.9820 - loss: 0.0520 - val_accuracy: 0.8406 - val_loss: 0.6930
# Epoch 6/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 364ms/step - accuracy: 0.9856 - loss: 0.0436 - val_accuracy: 0.8406 - val_loss: 0.6372
# Epoch 7/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 316ms/step - accuracy: 0.9820 - loss: 0.0492 - val_accuracy: 0.8406 - val_loss: 0.4931
# Epoch 8/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 333ms/step - accuracy: 0.9892 - loss: 0.0405 - val_accuracy: 0.8406 - val_loss: 0.7706
# Epoch 9/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 299ms/step - accuracy: 0.9748 - loss: 0.0403 - val_accuracy: 0.8406 - val_loss: 0.5995
# Epoch 10/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 328ms/step - accuracy: 0.9928 - loss: 0.0271 - val_accuracy: 0.8696 - val_loss: 0.7559
# Epoch 11/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 317ms/step - accuracy: 0.9928 - loss: 0.0173 - val_accuracy: 0.8406 - val_loss: 0.7788
# Epoch 12/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 298ms/step - accuracy: 0.9892 - loss: 0.0260 - val_accuracy: 0.8551 - val_loss: 0.8411
# Epoch 13/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 317ms/step - accuracy: 0.9964 - loss: 0.0194 - val_accuracy: 0.8406 - val_loss: 0.6818
# Epoch 14/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 331ms/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 0.8551 - val_loss: 0.6995
# Epoch 15/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 305ms/step - accuracy: 0.9928 - loss: 0.0270 - val_accuracy: 0.7826 - val_loss: 0.8850
# Epoch 16/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 317ms/step - accuracy: 0.9856 - loss: 0.0395 - val_accuracy: 0.8406 - val_loss: 0.7081
# Epoch 17/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 307ms/step - accuracy: 0.9856 - loss: 0.0378 - val_accuracy: 0.8551 - val_loss: 0.4633
# Epoch 18/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 289ms/step - accuracy: 0.9892 - loss: 0.0276 - val_accuracy: 0.8406 - val_loss: 0.5529
# Epoch 19/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 325ms/step - accuracy: 0.9820 - loss: 0.0458 - val_accuracy: 0.8406 - val_loss: 0.4732
# Epoch 20/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 314ms/step - accuracy: 0.9856 - loss: 0.0408 - val_accuracy: 0.8406 - val_loss: 0.5733

# %%
model.save("model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save("model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
print(train_generator.class_indices)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(train_generator.class_indices)
#
# NameError: name 'train_generator' is not defined

# %%
model.save("model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
print(train_generator.class_indices)

# %%
print(train_generator.class_indices)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print(train_generator.class_indices)
#
# NameError: name 'train_generator' is not defined

# %%
classes = ["blight", "gray_leaf", "healthy", "rust"]
