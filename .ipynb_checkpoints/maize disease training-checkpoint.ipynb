# %%
maize cnn training.ipynb

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np

# %%
print("All libraries working correctly")
# Out:
# All libraries working correctly

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_data = train_datagen.flow_from_directory(
    'dataset',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_data = train_datagen.flow_from_directory(
    'dataset',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 0 images belonging to 5 classes.
# Found 0 images belonging to 5 classes.

# %%
import os

print("CURRENT LOCATION:")
print(os.getcwd())

print("\nINSIDE CURRENT FOLDER:")
print(os.listdir('.'))

print("\nINSIDE DATASET FOLDER:")
print(os.listdir('dataset'))
# Out:
# CURRENT LOCATION:
# C:\Users\Rose\maize-disease-project
#
# INSIDE CURRENT FOLDER:
# ['.ipynb_checkpoints', 'dataset', 'maize disease training.ipynb', 'models', 'notebooks', 'static', 'templates']
#
# INSIDE DATASET FOLDER:
# ['.ipynb_checkpoints', 'common_rust', 'gray_leaf_spot', 'healthy', 'northern_leaf_blight']

# %%
import os

for folder in os.listdir('dataset'):
    path = os.path.join('dataset', folder)
    if os.path.isdir(path):
        print(folder, "->", len(os.listdir(path)))
# Out:
# .ipynb_checkpoints -> 0
# common_rust -> 0
# gray_leaf_spot -> 0
# healthy -> 0
# northern_leaf_blight -> 0

# %%
import os

print(os.listdir('dataset/healthy'))
# Out:
# ['img (1).jpg']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(rescale=1./255)

data = datagen.flow_from_directory(
    'dataset',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 1 images belonging to 5 classes.

# %%
import os

for folder in os.listdir('dataset'):
    print(folder, "->", len(os.listdir(f'dataset/{folder}')))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import os
# ----> 3 for folder in os.listdir('dataset'):
#       4     print(folder, "->", len(os.listdir(f'dataset/{folder}')))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'dataset'

# %%
import os

for folder in os.listdir("dataset"):
    path = os.path.join("dataset", folder)
    print(folder, "->", len(os.listdir(path)))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import os
# ----> 3 for folder in os.listdir("dataset"):
#       4     path = os.path.join("dataset", folder)
#       5     print(folder, "->", len(os.listdir(path)))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'dataset'

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Rose\maize-disease-project\.ipynb_checkpoints

# %%
import os

for folder in os.listdir("../dataset"):
    path = os.path.join("../dataset", folder)
    print(folder, "->", len(os.listdir(path)))
# Out:
# common_rust -> 72
# gray_leaf_spot -> 80
# healthy -> 120
# northern_leaf_blight -> 75

# %%
train_data = datagen.flow_from_directory(
    "../dataset",
    target_size=(128,128),
    batch_size=32,
    class_mode="categorical",
    subset="training"
)

val_data = datagen.flow_from_directory(
    "../dataset",
    target_size=(128,128),
    batch_size=32,
    class_mode="categorical",
    subset="validation"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 train_data = datagen.flow_from_directory(
#       2     "../dataset",
#       3     target_size=(128,128),
#       4     batch_size=32,
#       5     class_mode="categorical",
#       6     subset="training"
#       7 )
#       9 val_data = datagen.flow_from_directory(
#      10     "../dataset",
#      11     target_size=(128,128),
#    (...)
#      14     subset="validation"
#      15 )
#
# NameError: name 'datagen' is not defined
